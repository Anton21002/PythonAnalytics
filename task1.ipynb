# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn import datasets
from sklearn.model_selection import train_test_split , KFold
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

from collections import Counter

# %%
airsat=pd.read_csv('AirlineSatisfationData.csv')
airsat
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
#Removing unusable data
airsat.drop(['id','Gate location','Food and drink','Online boarding','Leg room service','Baggage handling','Cleanliness'],axis=1,inplace=True)
airsat
# Out:
#        Unnamed: 0  Gender      Customer Type  Age   Type of Travel     Class  \
# 0               0  Female     Loyal Customer   52  Business travel       Eco
# 1               1  Female     Loyal Customer   36  Business travel  Business
# 2               2    Male  disloyal Customer   20  Business travel       Eco
# 3               3    Male     Loyal Customer   44  Business travel  Business
# 4               4  Female     Loyal Customer   49  Business travel       Eco
# ...           ...     ...                ...  ...              ...       ...
# 25971       25971    Male  disloyal Customer   34  Business travel  Business
# 25972       25972    Male     Loyal Customer   23  Business travel  Business
# 25973       25973  Female     Loyal Customer   17  Personal Travel       Eco
# 25974       25974    Male     Loyal Customer   14  Business travel  Business
# 25975       25975  Female     Loyal Customer   42  Personal Travel       Eco
#
# ...

# %%
#renaming the datatypes to make it easier to read
airsat.rename(columns={'Customer Type':'CustomerType',
'Type of Travel':'TravelType',
'Flight Distance':'Distance',
'Inflight wifi service':'WifiQuality',
'Departure/Arrival time convenient':'TimeConvenience',
'Ease of Online booking':'BookingQuality',
'Seat comfort':'SeatQuality',
'Inflight entertainment':'EntertainmentQuality',
'On-board service':'OnboardServiceQuality',
'Checkin service':'CheckinQuality',
'Inflight service':'InflightServiceQuality',
'Departure Delay in Minutes':'DepartureDelayMIN',
'Arrival Delay in Minutes':'ArrivalDelayMIN',
'satisfaction':'Satisfaction',
})
# Out:
#        Unnamed: 0  Gender       CustomerType  Age       TravelType     Class  \
# 0               0  Female     Loyal Customer   52  Business travel       Eco
# 1               1  Female     Loyal Customer   36  Business travel  Business
# 2               2    Male  disloyal Customer   20  Business travel       Eco
# 3               3    Male     Loyal Customer   44  Business travel  Business
# 4               4  Female     Loyal Customer   49  Business travel       Eco
# ...           ...     ...                ...  ...              ...       ...
# 25971       25971    Male  disloyal Customer   34  Business travel  Business
# 25972       25972    Male     Loyal Customer   23  Business travel  Business
# 25973       25973  Female     Loyal Customer   17  Personal Travel       Eco
# 25974       25974    Male     Loyal Customer   14  Business travel  Business
# 25975       25975  Female     Loyal Customer   42  Personal Travel       Eco
#
# ...

# %%
print(airsat['Type of Travel'].value_counts())
# Out:
# Business travel    18038
# Personal Travel     7938
# Name: Type of Travel, dtype: int64

# %%
def TravelType_into_num(x):
        if x=='Business travel': return 0
        if x=='Personal Travel': return 1

# %%
from sklearn import preprocessing
x=airsat['Type of Travel'].apply(TravelType_into_num)
x=x.values.reshape(-1,1)
y=airsat['Flight Distance']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)

#Train the model using the training sets
knn.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(x_test)

# %%
knn.score(x_test, y_test)
# Out:
# 0.0005132811497497754
